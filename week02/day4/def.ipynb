# %%
def privet():
    return "Привет!"

balanceprivetov = 100
while balanceprivetov > 0:
    print("Хочу сказать привет:")
    print(privet())
    balanceprivetov -= 5
if balanceprivetov <= 0:
    print("Баланс приветов закончился")
# Out:
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Хочу сказать привет:
# Привет!
# Баланс приветов закончился

# %%
def name_person(name):
    print("Привет", ",", name, "!")

name_person("Karim")
name_person("Azat")
# Out:
# Привет , Karim !
# Привет , Azat !

# %%
def add_numbers(a, b):
    return a + b
    return result

sum_result = add_numbers(5, 10)
print(sum_result)
# Out:
# 15

# %%
def is_even(number):
    if number % 2 == 0:
        return True
    else:
        return False

number = 19
print("Число:",number)
print("Четное?", is_even(number))
number = 4
print("Число:",number)
print("Четное?", is_even(number))
# Out:
# Число: 19
# Четное? False
# Число: 4
# Четное? True

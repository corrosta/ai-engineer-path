# %%
skills = ["Git", "venv", "Jupyter", "Colab", "VSCode"]

for skill in skills:
    print(skill)
# Out:
# Git
# venv
# Jupyter
# Colab
# VSCode

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
my_progress = {
    "week": 2,
    "days_completed": 3,
    "hardest_topic": "Словари"
}

for key in my_progress:
    print(key, "-", my_progress[key])
# Out:
# week - 2
# days_completed - 3
# hardest_topic - Словари

# %%
count = 0
while count < 5:
    print("Счёт:", count)
    count += 1
# Out:
# Счёт: 0
# Счёт: 1
# Счёт: 2
# Счёт: 3
# Счёт: 4

# %%
numbers = [4, 15, 8, 23, 42, 7]
for number in numbers:
    if number >=10:
        print(number, "Больше десяти")
# Out:
# 15 Больше десяти
# 23 Больше десяти
# 42 Больше десяти

# %%
balance = 100
while balance > 0:
    print("Баланс:", balance)
    balance -= 15
# Out:
# Баланс: 100
# Баланс: 85
# Баланс: 70
# Баланс: 55
# Баланс: 40
# Баланс: 25
# Баланс: 10

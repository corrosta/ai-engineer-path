# %%
skills = ["Python", "Git", "Jupyter"]
print(skills)
print(skills[1])
print(skills[0])   # первый элемент
print(skills[2])   # третий элемент
print(len(skills)) # количество элементов
# Out:
# ['Python', 'Git', 'Jupyter']
# Git
# Python
# Jupyter
# 3

# %%
skills.append("Pandas")   # добавить в конец
print(skills)
# Out:
# ['Python', 'Git & GitHub', 'Jupyter', 'Pandas', 'Pandas']

# %%
skills.remove("Pandas")   # удалить по значению
print(skills)
# Out:
# ['Python', 'Git & GitHub', 'Jupyter', 'Pandas']

# %%
skills[1] = "Git & GitHub"  # изменить элемент по индексу
print(skills)
# Out:
# ['Python', 'Git & GitHub', 'Jupyter', 'Pandas']

# %%
profile = {
    "name": "Карим",
    "age": 22,
    "learning": "Python"
}
print(profile)
print(profile["name"])   # обращение по ключу
profile["age"] = 23       # изменить значение
profile["city"] = "Kazan"  # добавить новую пару
print(profile)
# Out:
# {'name': 'Карим', 'age': 22, 'learning': 'Python'}
# Карим
# {'name': 'Карим', 'age': 23, 'learning': 'Python', 'city': 'Kazan'}

# %%
skills = ["Git","venv","Jupiter","colab","VSCode"] #week1_topics

my_progress = {
    "week": [1,2],
    "days_completed": [1,2,3,4,5,6,7,8],
    "hardest_topic": "Словари и значения"
}
print(my_progress)

print(skills)
print(skills[1])
print(skills[0])
print(skills[2])
# Out:
# {'week': [1, 2], 'days_completed': [1, 2, 3, 4, 5, 6, 7, 8], 'hardest_topic': 'Словари и значения'}
# ['Git', 'venv', 'Jupiter', 'colab', 'VSCode']
# venv
# Git
# Jupiter

# %%
name = "KaRim"
print(name.upper())
print(name.capitalize())
print(name.lower())  

text = "  hello,world!   "
print(text.strip())
# Out:
# KARIM
# Karim
# karim
# hello,world!

# %%
text = "Я учу пайтон, это круто"
words = text.split()
print(words)
print(len(words))
# Out:
# ['Я', 'учу', 'пайтон,', 'это', 'круто']
# 5

# %%
name = "karim"
week = 2
print(f"Привет, {name.capitalize()}! Ты на неделе {week}. ")

print("Привет,", name, "! Ты на неделе", week)
# Out:
# Привет, Karim! Ты на неделе 2.
# Привет, karim ! Ты на неделе 2

# %%
import numpy as np

v1 = np.array([2, 3])
v2 = np.array([1, 5])

print(v1,v2)

result = v1+v2
print(result)

result1 = v1*3
print(result1)

np.dot(v1,v2)

length = np.linalg.norm(v1)
print(length)

a = np.array([5, 5])
b = np.array([3, 7])

c = np.array([5, 5])
d = np.array([-5, -5])

e = np.array([5, 0])
f = np.array([0, 5])

print(np.dot(a,b))
print(np.dot(c,d))
print(np.dot(e,f))
# Out:
# [2 3] [1 5]
# [3 8]
# [6 9]
# 3.605551275463989
# 50
# -50
# 0
